# %%
import sys, serial
from matplotlib import pyplot as plt
sample = []
# %matplotlib inline

for i in range(100):
    sample.append(i)
    plt.plot(sample)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a531bbcc7c98> in <module>()
#       6 for i in range(100):
#       7     sample.append(i)
# ----> 8     plt.plot(sample)
#       9     plt.show()
#      10
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2458 @autogen_docstring(Axes.plot)
#    2459 def plot(*args, **kwargs):
# -> 2460     ax = gca()
#    2461     # allow callers to override the hold state by passing hold=True|False
#    2462     washold = ax.ishold()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in gca(**kwargs)
#     699     """
#     700
# --> 701     ax =  gcf().gca(**kwargs)
#     702     return ax
#     703
#
# ...
